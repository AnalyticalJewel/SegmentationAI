# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder,StandardScaler
from sklearn.model_selection import train_test_split

# %%
data=pd.read_csv('data.csv')
data.head(50)
# Out:
#     Customer ID  Age Gender Item Purchased     Category  \
# 0             1   55   Male         Blouse     Clothing
# 1             2   19   Male        Sweater     Clothing
# 2             3   50   Male          Jeans     Clothing
# 3             4   21   Male        Sandals     Footwear
# 4             5   45   Male         Blouse     Clothing
# 5             6   46   Male       Sneakers     Footwear
# 6             7   63   Male          Shirt     Clothing
# 7             8   27   Male         Shorts     Clothing
# 8             9   26   Male           Coat    Outerwear
# 9            10   57   Male        Handbag  Accessories
# 10           11   53   Male          Shoes     Footwear
# 11           12   30   Male         Shorts     Clothing
# 12           13   61   Male           Coat    Outerwear
# 13           14   65   Male          Dress     Clothing
# 14           15   64   Male           Coat    Outerwear
# 15           16   64   Male          Skirt     Clothing
# 16           17   25   Male     Sunglasses  Accessories
# 17           18   53   Male          Dress     Clothing
# 18           19   52   Male        Sweater     Clothing
# 19           20   66   Male          Pants     Clothing
# 20           21   21   Male          Pants     Clothing
# 21           22   31   Male          Pants     Clothing
# 22           23   56   Male          Pants     Clothing
# 23           24   31   Male          Pants     Clothing
# 24           25   18   Male         Jacket    Outerwear
# 25           26   18   Male         Hoodie     Clothing
# 26           27   38   Male        Jewelry  Accessories
# 27           28   56   Male         Shorts     Clothing
# 28           29   54   Male        Handbag  Accessories
# 29           30   31   Male          Dress     Clothing
# 30           31   57   Male        Jewelry  Accessories
# 31           32   33   Male          Dress     Clothing
# 32           33   36   Male         Jacket    Outerwear
# 33           34   54   Male          Pants     Clothing
# 34           35   36   Male        T-shirt     Clothing
# 35           36   54   Male         Blouse     Clothing
# 36           37   35   Male        T-shirt     Clothing
# 37           38   35   Male          Jeans     Clothing
# 38           39   29   Male          Dress     Clothing
# 39           40   70   Male          Pants     Clothing
# 40           41   69   Male        Handbag  Accessories
# 41           42   67   Male          Scarf  Accessories
# 42           43   20   Male           Coat    Outerwear
# 43           44   25   Male          Scarf  Accessories
# 44           45   39   Male            Hat  Accessories
# 45           46   50   Male          Socks     Clothing
# 46           47   57   Male          Shirt     Clothing
# 47           48   55   Male        Jewelry  Accessories
# 48           49   42   Male          Shirt     Clothing
# 49           50   68   Male         Hoodie     Clothing
#
#     Purchase Amount (USD)        Location Size      Color  Season  \
# 0                      53        Kentucky    L       Gray  Winter
# 1                      64           Maine    L     Maroon  Winter
# 2                      73   Massachusetts    S     Maroon  Spring
# 3                      90    Rhode Island    M     Maroon  Spring
# 4                      49          Oregon    M  Turquoise  Spring
# 5                      20         Wyoming    M      White  Summer
# 6                      85         Montana    M       Gray    Fall
# 7                      34       Louisiana    L   Charcoal  Winter
# 8                      97   West Virginia    L     Silver  Summer
# 9                      31        Missouri    M       Pink  Spring
# 10                     34        Arkansas    L     Purple    Fall
# 11                     68          Hawaii    S      Olive  Winter
# 12                     72        Delaware    M       Gold  Winter
# 13                     51   New Hampshire    M     Violet  Spring
# 14                     53        New York    L       Teal  Winter
# 15                     81    Rhode Island    M       Teal  Winter
# 16                     36         Alabama    S       Gray  Spring
# 17                     38     Mississippi   XL   Lavender  Winter
# 18                     48         Montana    S      Black  Summer
# 19                     90    Rhode Island    M      Green  Summer
# 20                     51       Louisiana    M      Black  Winter
# 21                     62  North Carolina    M   Charcoal  Winter
# 22                     37      California    M      Peach  Summer
# 23                     88        Oklahoma   XL      White  Winter
# 24                     22         Florida    M      Green    Fall
# 25                     25           Texas    M     Silver  Summer
# 26                     20          Nevada    M        Red  Spring
# 27                     56        Kentucky    L       Cyan  Summer
# 28                     94  North Carolina    M       Gray    Fall
# 29                     48         Wyoming    S      Black    Fall
# 30                     31  North Carolina    L      Black  Winter
# 31                     79   West Virginia    L      Brown  Winter
# 32                     67          Kansas    M     Silver  Summer
# 33                     38        Colorado    L      Green  Summer
# 34                     91    North Dakota    L     Violet  Spring
# 35                     33   Massachusetts    M       Cyan  Summer
# 36                     69        Illinois    M     Maroon  Winter
# 37                     45         Indiana    S       Cyan  Summer
# 38                     37         Florida    M        Red  Winter
# 39                     60         Arizona    S  Turquoise  Summer
# 40                     76       Louisiana    L      Beige  Winter
# 41                     39          Alaska    M     Orange  Spring
# 42                    100       Tennessee    M      Beige  Spring
# 43                     69            Ohio    L   Lavender    Fall
# 44                     53        Kentucky    S     Silver  Summer
# 45                     21       Tennessee   XL     Indigo    Fall
# 46                     43      California    L      White  Summer
# 47                     54         Montana    M   Charcoal  Winter
# 48                     55          Nevada    M     Orange  Summer
# 49                     30      New Jersey    S     Indigo  Spring
#
#     Review Rating Subscription Status   Shipping Type Discount Applied  \
# 0             3.1                 Yes         Express              Yes
# 1             3.1                 Yes         Express              Yes
# 2             3.1                 Yes   Free Shipping              Yes
# 3             3.5                 Yes    Next Day Air              Yes
# 4             2.7                 Yes   Free Shipping              Yes
# 5             2.9                 Yes        Standard              Yes
# 6             3.2                 Yes   Free Shipping              Yes
# 7             3.2                 Yes   Free Shipping              Yes
# 8             2.6                 Yes         Express              Yes
# 9             4.8                 Yes  2-Day Shipping              Yes
# 10            4.1                 Yes    Store Pickup              Yes
# 11            4.9                 Yes    Store Pickup              Yes
# 12            4.5                 Yes         Express              Yes
# 13            4.7                 Yes         Express              Yes
# 14            4.7                 Yes   Free Shipping              Yes
# 15            2.8                 Yes    Store Pickup              Yes
# 16            4.1                 Yes    Next Day Air              Yes
# 17            4.7                 Yes  2-Day Shipping              Yes
# 18            4.6                 Yes   Free Shipping              Yes
# 19            3.3                 Yes        Standard              Yes
# 20            2.8                 Yes         Express              Yes
# 21            4.1                 Yes    Store Pickup              Yes
# 22            3.2                 Yes    Store Pickup              Yes
# 23            4.4                 Yes         Express              Yes
# 24            2.9                 Yes    Store Pickup              Yes
# 25            3.6                 Yes         Express              Yes
# 26            3.6                 Yes    Next Day Air              Yes
# 27            5.0                 Yes    Next Day Air              Yes
# 28            4.4                 Yes   Free Shipping              Yes
# 29            4.1                 Yes    Store Pickup              Yes
# 30            4.7                 Yes        Standard              Yes
# 31            4.7                 Yes    Store Pickup              Yes
# 32            4.9                 Yes   Free Shipping              Yes
# 33            3.3                 Yes    Store Pickup              Yes
# 34            4.6                 Yes  2-Day Shipping              Yes
# 35            4.0                 Yes  2-Day Shipping              Yes
# 36            4.6                 Yes   Free Shipping              Yes
# 37            2.8                 Yes    Store Pickup              Yes
# 38            3.7                 Yes  2-Day Shipping              Yes
# 39            4.2                 Yes         Express              Yes
# 40            4.6                 Yes    Next Day Air              Yes
# 41            4.5                 Yes        Standard              Yes
# 42            4.1                 Yes   Free Shipping              Yes
# 43            3.7                 Yes    Store Pickup              Yes
# 44            4.6                 Yes   Free Shipping              Yes
# 45            2.9                 Yes  2-Day Shipping              Yes
# 46            2.9                 Yes    Store Pickup              Yes
# 47            4.5                 Yes   Free Shipping              Yes
# 48            2.7                 Yes    Store Pickup              Yes
# 49            4.6                 Yes    Next Day Air              Yes
#
#    Promo Code Used  Previous Purchases Payment Method Frequency of Purchases
# 0              Yes                  14          Venmo            Fortnightly
# 1              Yes                   2           Cash            Fortnightly
# 2              Yes                  23    Credit Card                 Weekly
# 3              Yes                  49         PayPal                 Weekly
# 4              Yes                  31         PayPal               Annually
# 5              Yes                  14          Venmo                 Weekly
# 6              Yes                  49           Cash              Quarterly
# 7              Yes                  19    Credit Card                 Weekly
# 8              Yes                   8          Venmo               Annually
# 9              Yes                   4           Cash              Quarterly
# 10             Yes                  26  Bank Transfer              Bi-Weekly
# 11             Yes                  10  Bank Transfer            Fortnightly
# 12             Yes                  37          Venmo            Fortnightly
# 13             Yes                  31         PayPal                 Weekly
# 14             Yes                  34     Debit Card                 Weekly
# 15             Yes                   8         PayPal                Monthly
# 16             Yes                  44     Debit Card              Bi-Weekly
# 17             Yes                  36          Venmo              Quarterly
# 18             Yes                  17           Cash                 Weekly
# 19             Yes                  46     Debit Card              Bi-Weekly
# 20             Yes                  50           Cash         Every 3 Months
# 21             Yes                  22     Debit Card              Quarterly
# 22             Yes                  32     Debit Card               Annually
# 23             Yes                  40    Credit Card                 Weekly
# 24             Yes                  16     Debit Card                 Weekly
# 25             Yes                  14         PayPal               Annually
# 26             Yes                  13    Credit Card               Annually
# 27             Yes                   7  Bank Transfer         Every 3 Months
# 28             Yes                  41         PayPal         Every 3 Months
# 29             Yes                  14    Credit Card                 Weekly
# 30             Yes                  16    Credit Card                Monthly
# 31             Yes                  45          Venmo                Monthly
# 32             Yes                  37          Venmo               Annually
# 33             Yes                  45           Cash              Quarterly
# 34             Yes                  38         PayPal              Quarterly
# 35             Yes                  48    Credit Card              Bi-Weekly
# 36             Yes                  44         PayPal            Fortnightly
# 37             Yes                  10         PayPal                 Weekly
# 38             Yes                  44          Venmo         Every 3 Months
# 39             Yes                  18    Credit Card                Monthly
# 40             Yes                  31     Debit Card              Quarterly
# 41             Yes                  40          Venmo               Annually
# 42             Yes                  15         PayPal               Annually
# 43             Yes                  19         PayPal            Fortnightly
# 44             Yes                  45         PayPal                 Weekly
# 45             Yes                  25         PayPal               Annually
# 46             Yes                  45           Cash              Quarterly
# 47             Yes                  36           Cash                 Weekly
# 48             Yes                  38           Cash                Monthly
# 49             Yes                  34     Debit Card              Bi-Weekly

# %%
data.dtypes
# Out:
# Customer ID                 int64
# Age                         int64
# Gender                     object
# Item Purchased             object
# Category                   object
# Purchase Amount (USD)       int64
# Location                   object
# Size                       object
# Color                      object
# Season                     object
# Review Rating             float64
# Subscription Status        object
# Shipping Type              object
# Discount Applied           object
# Promo Code Used            object
# Previous Purchases          int64
# Payment Method             object
# Frequency of Purchases     object
# dtype: object

# %%
#See the row with the missing value:
rows_with_missing_values = data[data.isnull().any(axis=1)]
rows_with_missing_values
# Out:
# Empty DataFrame
# Columns: [Customer ID, Age, Gender, Item Purchased, Category, Purchase Amount (USD), Location, Size, Color, Season, Review Rating, Subscription Status, Shipping Type, Discount Applied, Promo Code Used, Previous Purchases, Payment Method, Frequency of Purchases]
# Index: []

# %%
# Drop the  rows with missing values
data.dropna(inplace=True)
data.head(1)
# Out:
#    Customer ID  Age Gender Item Purchased  Category  Purchase Amount (USD)  \
# 0            1   55   Male         Blouse  Clothing                     53
#
#    Location Size Color  Season  Review Rating Subscription Status  \
# 0  Kentucky    L  Gray  Winter            3.1                 Yes
#
#   Shipping Type Discount Applied Promo Code Used  Previous Purchases  \
# 0       Express              Yes             Yes                  14
#
#   Payment Method Frequency of Purchases
# 0          Venmo            Fortnightly

# %%
data['Gender'].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
#Mapping gender column:
gender_mapping={
    'Male': 1,
    'Female' : 0
}
data['Gender']=data['Gender'].map(gender_mapping)

# %%
pd.options.display.max_columns=None
pd.options.display.max_rows=None

# %%
# Shuffle the dataset
data= data.sample(frac=1, random_state=42).reset_index(drop=True)
data.head(5)
# Out:
#    Customer ID  Age  Gender Item Purchased  Category  Purchase Amount (USD)  \
# 0          840   48       1          Shirt  Clothing                     31
# 1         1718   29       1         Hoodie  Clothing                     50
# 2          322   41       1       Sneakers  Footwear                     36
# 3         3188   67       0         Blouse  Clothing                     72
# 4         2270   49       1          Skirt  Clothing                     38
#
#    Location Size   Color  Season  Review Rating Subscription Status  \
# 0  Illinois    L    Teal  Spring            2.6                 Yes
# 1    Hawaii    L  Orange  Summer            2.9                  No
# 2   Vermont    L  Orange  Summer            4.7                 Yes
# 3     Texas    L  Indigo  Winter            3.2                  No
# 4  Kentucky    M  Yellow    Fall            4.4                  No
#
#    Shipping Type Discount Applied Promo Code Used  Previous Purchases  \
# 0  Free Shipping              Yes             Yes                  10
# 1        Express               No              No                  16
# 2  Free Shipping              Yes             Yes                  48
# 3  Free Shipping               No              No                  28
# 4   Store Pickup               No              No                  27
#
#   Payment Method Frequency of Purchases
# 0     Debit Card         Every 3 Months
# 1     Debit Card              Bi-Weekly
# 2     Debit Card              Quarterly
# 3     Debit Card                 Weekly
# 4    Credit Card               Annually

# %%
data['Item Purchased'].unique()
# Out:
# array(['Shirt', 'Hoodie', 'Sneakers', 'Blouse', 'Skirt', 'Socks', 'Pants',
#        'Jeans', 'Coat', 'Belt', 'Gloves', 'Handbag', 'Sunglasses',
#        'Sweater', 'Boots', 'Dress', 'Backpack', 'Sandals', 'Hat',
#        'Jacket', 'Shorts', 'Shoes', 'Scarf', 'Jewelry', 'T-shirt'],
#       dtype=object)

# %%
data['Category'].unique()
# Out:
# array(['Clothing', 'Footwear', 'Outerwear', 'Accessories'], dtype=object)

# %%
item_mapping = {
    'Shirt': 1,
    'Hoodie': 2,
    'Sneakers': 3,
    'Blouse': 4,
    'Skirt': 5,
    'Socks': 6,
    'Pants': 7,
    'Jeans': 8,
    'Coat': 9,
    'Belt': 10,
    'Gloves': 11,
    'Handbag': 12,
    'Sunglasses': 13,
    'Sweater': 14,
    'Boots': 15,
    'Dress': 16,
    'Backpack': 17,
    'Sandals': 18,
    'Hat': 19,
    'Jacket': 20,
    'Shorts': 21,
    'Shoes': 22,
    'Scarf': 23,
    'Jewelry': 24,
    'T-shirt': 25
}

category_mapping = {
    'Accessories': 1,
    'Clothing': 2,
    'Footwear': 3,
    'Outerwear': 4
}

# Map Item Purchased to numerical values
data['Item Purchased'] = data['Item Purchased'].map(item_mapping)
data['Category']=data['Category'].map(category_mapping)

# %%
data.head(10)
# Out:
#    Customer ID  Age  Gender  Item Purchased  Category  Purchase Amount (USD)  \
# 0          840   48       1               1         2                     31
# 1         1718   29       1               2         2                     50
# 2          322   41       1               3         3                     36
# 3         3188   67       0               4         2                     72
# 4         2270   49       1               5         2                     38
# 5          367   64       1               6         2                     36
# 6         2645   25       1               7         2                     83
# 7         1750   43       1               2         2                     70
# 8         3606   68       0               8         2                     41
# 9         1097   57       1               9         4                     46
#
#         Location Size      Color  Season  Review Rating Subscription Status  \
# 0       Illinois    L       Teal  Spring            2.6                 Yes
# 1         Hawaii    L     Orange  Summer            2.9                  No
# 2        Vermont    L     Orange  Summer            4.7                 Yes
# 3          Texas    L     Indigo  Winter            3.2                  No
# 4       Kentucky    M     Yellow    Fall            4.4                  No
# 5       Nebraska    M  Turquoise  Spring            3.5                 Yes
# 6     New Mexico    M  Turquoise  Spring            3.3                  No
# 7        Wyoming    L       Pink    Fall            3.2                  No
# 8        Alabama    M       Gold    Fall            4.3                  No
# 9  New Hampshire    S      Beige    Fall            2.6                  No
#
#     Shipping Type Discount Applied Promo Code Used  Previous Purchases  \
# 0   Free Shipping              Yes             Yes                  10
# 1         Express               No              No                  16
# 2   Free Shipping              Yes             Yes                  48
# 3   Free Shipping               No              No                  28
# 4    Store Pickup               No              No                  27
# 5    Store Pickup              Yes             Yes                  37
# 6        Standard               No              No                   4
# 7  2-Day Shipping               No              No                  36
# 8    Store Pickup               No              No                  36
# 9        Standard              Yes             Yes                  48
#
#   Payment Method Frequency of Purchases
# 0     Debit Card         Every 3 Months
# 1     Debit Card              Bi-Weekly
# 2     Debit Card              Quarterly
# 3     Debit Card                 Weekly
# 4    Credit Card               Annually
# 5          Venmo            Fortnightly
# 6  Bank Transfer         Every 3 Months
# 7     Debit Card         Every 3 Months
# 8  Bank Transfer         Every 3 Months
# 9    Credit Card               Annually

# %%
data.rename(columns={'Item Purchased': 'Item(code) Purchased','Category':'Item Category'}, inplace=True)
data.head(3)
# Out:
#    Customer ID  Age  Gender  Item(code) Purchased  Item Category  \
# 0          840   48       1                     1              2
# 1         1718   29       1                     2              2
# 2          322   41       1                     3              3
#
#    Purchase Amount (USD)  Location Size   Color  Season  Review Rating  \
# 0                     31  Illinois    L    Teal  Spring            2.6
# 1                     50    Hawaii    L  Orange  Summer            2.9
# 2                     36   Vermont    L  Orange  Summer            4.7
#
#   Subscription Status  Shipping Type Discount Applied Promo Code Used  \
# 0                 Yes  Free Shipping              Yes             Yes
# 1                  No        Express               No              No
# 2                 Yes  Free Shipping              Yes             Yes
#
#    Previous Purchases Payment Method Frequency of Purchases
# 0                  10     Debit Card         Every 3 Months
# 1                  16     Debit Card              Bi-Weekly
# 2                  48     Debit Card              Quarterly

# %%
data['Location'].unique()
# Out:
# array(['Illinois', 'Hawaii', 'Vermont', 'Texas', 'Kentucky', 'Nebraska',
#        'New Mexico', 'Wyoming', 'Alabama', 'New Hampshire', 'New York',
#        'Utah', 'Kansas', 'Colorado', 'Michigan', 'Montana', 'Indiana',
#        'Oklahoma', 'Tennessee', 'Nevada', 'California', 'Maryland',
#        'Alaska', 'Wisconsin', 'North Dakota', 'Missouri', 'Delaware',
#        'Arkansas', 'Minnesota', 'Louisiana', 'Mississippi', 'Connecticut',
#        'Idaho', 'Ohio', 'South Carolina', 'Iowa', 'Georgia', 'Washington',
#        'Florida', 'South Dakota', 'Arizona', 'West Virginia', 'Maine',
#        'New Jersey', 'Pennsylvania', 'Virginia', 'Rhode Island',
#        'Massachusetts', 'North Carolina', 'Oregon'], dtype=object)

# %%
# Create a mapping for locations to integers based on the starting letter
location_mapping = {
    'Alabama': 1,
    'Alaska': 2,
    'Arizona': 3,
    'Arkansas': 4,
    'California': 5,
    'Colorado': 6,
    'Connecticut': 7,
    'Delaware': 8,
    'Florida': 9,
    'Georgia': 10,
    'Hawaii': 11,
    'Idaho': 12,
    'Illinois': 13,
    'Indiana': 14,
    'Iowa': 15,
    'Kansas': 16,
    'Kentucky': 17,
    'Louisiana': 18,
    'Maine': 19,
    'Maryland': 20,
    'Massachusetts': 21,
    'Michigan': 22,
    'Minnesota': 23,
    'Mississippi': 24,
    'Missouri': 25,
    'Montana': 26,
    'Nebraska': 27,
    'Nevada': 28,
    'New Hampshire': 29,
    'New Jersey': 30,
    'New Mexico': 31,
    'New York': 32,
    'North Carolina': 33,
    'North Dakota': 34,
    'Ohio': 35,
    'Oklahoma': 36,
    'Oregon': 37,
    'Pennsylvania': 38,
    'Rhode Island': 39,
    'South Carolina': 40,
    'South Dakota': 41,
    'Tennessee': 42,
    'Texas': 43,
    'Utah': 44,
    'Vermont': 45,
    'Virginia': 46,
    'Washington': 47,
    'West Virginia': 48,
    'Wisconsin': 49,
    'Wyoming': 50
}

# Map Location to numerical values
data['Location'] = data['Location'].map(location_mapping)

data.head(50)
# Out:
#     Customer ID  Age  Gender  Item(code) Purchased  Item Category  \
# 0           840   48       1                     1              2
# 1          1718   29       1                     2              2
# 2           322   41       1                     3              3
# 3          3188   67       0                     4              2
# 4          2270   49       1                     5              2
# 5           367   64       1                     6              2
# 6          2645   25       1                     7              2
# 7          1750   43       1                     2              2
# 8          3606   68       0                     8              2
# 9          1097   57       1                     9              4
# 10         2601   21       1                    10              1
# 11         1660   53       1                    11              1
# 12         3888   40       0                     1              2
# 13         3498   35       0                    12              1
# 14         3653   27       0                    12              1
# 15         1537   18       1                    13              1
# 16         2737   44       0                     2              2
# 17           15   64       1                     9              4
# 18         1026   60       1                     1              2
# 19         3255   21       0                    14              2
# 20         2182   22       1                    12              1
# 21          433   47       1                     1              2
# 22         2010   37       1                    15              3
# 23          865   51       1                     8              2
# 24         1957   70       1                     6              2
# 25          323   41       1                    10              1
# 26         2400   55       1                    16              2
# 27         3832   36       0                    17              1
# 28         1118   25       1                    13              1
# 29         3130   60       0                    18              3
# 30         2515   42       1                    19              1
# 31         2579   54       1                    13              1
# 32           33   36       1                    20              4
# 33         1147   48       1                     3              3
# 34         2356   22       1                     5              2
# 35         3221   38       0                    12              1
# 36         1962   47       1                    15              3
# 37         3706   28       0                     5              2
# 38         2668   48       0                    15              3
# 39         3578   66       0                    10              1
# 40         3854   61       0                    13              1
# 41         2859   34       0                     8              2
# 42          150   38       1                     7              2
# 43         1887   18       1                    11              1
# 44          872   47       1                    12              1
# 45         1399   30       1                    16              2
# 46         2438   43       1                     3              3
# 47         1966   67       1                    14              2
# 48         1042   36       1                     1              2
# 49          786   46       1                    21              2
#
#     Purchase Amount (USD)  Location Size      Color  Season  Review Rating  \
# 0                      31        13    L       Teal  Spring            2.6
# 1                      50        11    L     Orange  Summer            2.9
# 2                      36        45    L     Orange  Summer            4.7
# 3                      72        43    L     Indigo  Winter            3.2
# 4                      38        17    M     Yellow    Fall            4.4
# 5                      36        27    M  Turquoise  Spring            3.5
# 6                      83        31    M  Turquoise  Spring            3.3
# 7                      70        50    L       Pink    Fall            3.2
# 8                      41         1    M       Gold    Fall            4.3
# 9                      46        29    S      Beige    Fall            2.6
# 10                     83        32    M       Gray    Fall            3.9
# 11                     37        44    M      Black    Fall            3.9
# 12                     34        16    M   Charcoal  Spring            2.7
# 13                     48         6    M        Red  Spring            4.3
# 14                     29        17    S    Magenta    Fall            3.8
# 15                     82        22    M     Indigo  Summer            2.6
# 16                     25        26    M       Pink  Spring            4.8
# 17                     53        32    L       Teal  Winter            4.7
# 18                     84        27    M      Olive  Winter            4.9
# 19                     31        14    S    Magenta  Winter            4.9
# 20                     63        11    M      Black    Fall            3.2
# 21                     86        14    S     Indigo    Fall            3.3
# 22                     99         1    M     Indigo  Summer            3.8
# 23                     59        17    S   Charcoal  Winter            3.9
# 24                     37        36    M       Pink  Winter            4.9
# 25                     95        42    S       Cyan  Winter            3.0
# 26                     44        29    L      Beige  Spring            3.2
# 27                     86        28    L     Silver  Spring            4.0
# 28                     77         5    L   Lavender  Spring            4.5
# 29                     20        20    S       Cyan  Summer            4.7
# 30                     37         2    L       Teal  Spring            4.8
# 31                     48        45    M     Purple    Fall            3.9
# 32                     67        16    M     Silver  Summer            4.9
# 33                     38        49    M     Indigo  Summer            4.2
# 34                     35        42    S     Purple  Winter            4.1
# 35                     29        34    M       Blue    Fall            4.1
# 36                     59        28    L      Black  Summer            2.6
# 37                     65         6    L       Teal  Summer            3.2
# 38                     47        20    M     Orange  Summer            4.1
# 39                     35        25    S     Yellow  Winter            2.6
# 40                     76        42    M   Lavender    Fall            4.0
# 41                     87        20    L       Teal  Summer            3.8
# 42                     76         8    M      White  Summer            3.2
# 43                     91         4    L      Beige  Spring            4.4
# 44                     42        11    M   Charcoal  Spring            2.6
# 45                     45        43    M       Cyan  Summer            2.5
# 46                     59        50   XL    Magenta  Winter            3.4
# 47                     90        14    M      White    Fall            4.9
# 48                     25        23    M     Orange  Summer            4.9
# 49                     62        18    S     Purple  Spring            4.0
#
#    Subscription Status   Shipping Type Discount Applied Promo Code Used  \
# 0                  Yes   Free Shipping              Yes             Yes
# 1                   No         Express               No              No
# 2                  Yes   Free Shipping              Yes             Yes
# 3                   No   Free Shipping               No              No
# 4                   No    Store Pickup               No              No
# 5                  Yes    Store Pickup              Yes             Yes
# 6                   No        Standard               No              No
# 7                   No  2-Day Shipping               No              No
# 8                   No    Store Pickup               No              No
# 9                   No        Standard              Yes             Yes
# 10                  No         Express               No              No
# 11                  No    Next Day Air              Yes             Yes
# 12                  No         Express               No              No
# 13                  No    Store Pickup               No              No
# 14                  No    Store Pickup               No              No
# 15                  No    Store Pickup              Yes             Yes
# 16                  No    Store Pickup               No              No
# 17                 Yes   Free Shipping              Yes             Yes
# 18                 Yes   Free Shipping              Yes             Yes
# 19                  No    Store Pickup               No              No
# 20                  No   Free Shipping               No              No
# 21                 Yes   Free Shipping              Yes             Yes
# 22                  No    Next Day Air               No              No
# 23                 Yes    Next Day Air              Yes             Yes
# 24                  No         Express               No              No
# 25                 Yes        Standard              Yes             Yes
# 26                  No    Store Pickup               No              No
# 27                  No    Next Day Air               No              No
# 28                  No    Store Pickup              Yes             Yes
# 29                  No         Express               No              No
# 30                  No   Free Shipping               No              No
# 31                  No   Free Shipping               No              No
# 32                 Yes   Free Shipping              Yes             Yes
# 33                  No        Standard              Yes             Yes
# 34                  No    Next Day Air               No              No
# 35                  No   Free Shipping               No              No
# 36                  No   Free Shipping               No              No
# 37                  No   Free Shipping               No              No
# 38                  No   Free Shipping               No              No
# 39                  No        Standard               No              No
# 40                  No    Store Pickup               No              No
# 41                  No  2-Day Shipping               No              No
# 42                 Yes   Free Shipping              Yes             Yes
# 43                  No    Next Day Air               No              No
# 44                 Yes    Next Day Air              Yes             Yes
# 45                  No   Free Shipping              Yes             Yes
# 46                  No    Store Pickup               No              No
# 47                  No         Express               No              No
# 48                 Yes    Next Day Air              Yes             Yes
# 49                 Yes    Next Day Air              Yes             Yes
#
#     Previous Purchases Payment Method Frequency of Purchases
# 0                   10     Debit Card         Every 3 Months
# 1                   16     Debit Card              Bi-Weekly
# 2                   48     Debit Card              Quarterly
# 3                   28     Debit Card                 Weekly
# 4                   27    Credit Card               Annually
# 5                   37          Venmo            Fortnightly
# 6                    4  Bank Transfer         Every 3 Months
# 7                   36     Debit Card         Every 3 Months
# 8                   36  Bank Transfer         Every 3 Months
# 9                   48    Credit Card               Annually
# 10                   6  Bank Transfer              Bi-Weekly
# 11                  44          Venmo               Annually
# 12                   1    Credit Card              Quarterly
# 13                  16          Venmo         Every 3 Months
# 14                  23     Debit Card                Monthly
# 15                  17           Cash              Quarterly
# 16                  45    Credit Card               Annually
# 17                  34     Debit Card                 Weekly
# 18                  15    Credit Card               Annually
# 19                  11  Bank Transfer         Every 3 Months
# 20                  32  Bank Transfer              Bi-Weekly
# 21                  26          Venmo                 Weekly
# 22                  26          Venmo              Bi-Weekly
# 23                   5         PayPal               Annually
# 24                  20    Credit Card            Fortnightly
# 25                  47    Credit Card                Monthly
# 26                  31           Cash                Monthly
# 27                  16     Debit Card         Every 3 Months
# 28                  24    Credit Card                Monthly
# 29                  40          Venmo         Every 3 Months
# 30                  45         PayPal              Bi-Weekly
# 31                   3           Cash              Quarterly
# 32                  37          Venmo               Annually
# 33                   7  Bank Transfer         Every 3 Months
# 34                  12           Cash                Monthly
# 35                  16           Cash                Monthly
# 36                  45     Debit Card              Quarterly
# 37                   2     Debit Card               Annually
# 38                  31           Cash            Fortnightly
# 39                  13  Bank Transfer                 Weekly
# 40                  49     Debit Card              Bi-Weekly
# 41                  46  Bank Transfer                Monthly
# 42                  14         PayPal                Monthly
# 43                  46           Cash              Bi-Weekly
# 44                  45     Debit Card              Quarterly
# 45                  25    Credit Card                 Weekly
# 46                  34    Credit Card                 Weekly
# 47                  25     Debit Card              Quarterly
# 48                  11           Cash            Fortnightly
# 49                  37         PayPal            Fortnightly

# %%
data.head(3)
# Out:
#    Customer ID  Age  Gender  Item(code) Purchased  Item Category  \
# 0          840   48       1                     1              2
# 1         1718   29       1                     2              2
# 2          322   41       1                     3              3
#
#    Purchase Amount (USD)  Location Size   Color  Season  Review Rating  \
# 0                     31        13    L    Teal  Spring            2.6
# 1                     50        11    L  Orange  Summer            2.9
# 2                     36        45    L  Orange  Summer            4.7
#
#   Subscription Status  Shipping Type Discount Applied Promo Code Used  \
# 0                 Yes  Free Shipping              Yes             Yes
# 1                  No        Express               No              No
# 2                 Yes  Free Shipping              Yes             Yes
#
#    Previous Purchases Payment Method Frequency of Purchases
# 0                  10     Debit Card         Every 3 Months
# 1                  16     Debit Card              Bi-Weekly
# 2                  48     Debit Card              Quarterly

# %%
data['Size'].unique()
# Out:
# array(['L', 'M', 'S', 'XL'], dtype=object)

# %%
# Mapping for Size to numerical values
size_mapping = {
    'S': 1,
    'M': 2,
    'L': 3,
    'XL': 4
}

# Map Size to numerical values
data['Size'] = data['Size'].map(size_mapping)
data.head(3)
# Out:
#    Customer ID  Age  Gender  Item(code) Purchased  Item Category  \
# 0          840   48       1                     1              2
# 1         1718   29       1                     2              2
# 2          322   41       1                     3              3
#
#    Purchase Amount (USD)  Location  Size   Color  Season  Review Rating  \
# 0                     31        13     3    Teal  Spring            2.6
# 1                     50        11     3  Orange  Summer            2.9
# 2                     36        45     3  Orange  Summer            4.7
#
#   Subscription Status  Shipping Type Discount Applied Promo Code Used  \
# 0                 Yes  Free Shipping              Yes             Yes
# 1                  No        Express               No              No
# 2                 Yes  Free Shipping              Yes             Yes
#
#    Previous Purchases Payment Method Frequency of Purchases
# 0                  10     Debit Card         Every 3 Months
# 1                  16     Debit Card              Bi-Weekly
# 2                  48     Debit Card              Quarterly

# %%
data['Color'].unique()
# Out:
# array(['Teal', 'Orange', 'Indigo', 'Yellow', 'Turquoise', 'Pink', 'Gold',
#        'Beige', 'Gray', 'Black', 'Charcoal', 'Red', 'Magenta', 'Olive',
#        'Cyan', 'Silver', 'Lavender', 'Purple', 'Blue', 'White', 'Maroon',
#        'Violet', 'Green', 'Brown', 'Peach'], dtype=object)

# %%
# Mapping for Color to numerical values
color_mapping = {
    'Teal': 1,
    'Orange': 2,
    'Indigo': 3,
    'Yellow': 4,
    'Turquoise': 5,
    'Pink': 6,
    'Gold': 7,
    'Beige': 8,
    'Gray': 9,
    'Black': 10,
    'Charcoal': 11,
    'Red': 12,
    'Magenta': 13,
    'Olive': 14,
    'Cyan': 15,
    'Silver': 16,
    'Lavender': 17,
    'Purple': 18,
    'Blue': 19,
    'White': 20,
    'Maroon': 21,
    'Violet': 22,
    'Green': 23,
    'Brown': 24,
    'Peach': 25
}

# Map Color to numerical values
data['Color'] = data['Color'].map(color_mapping)
data.head(10)
# Out:
#    Customer ID  Age  Gender  Item(code) Purchased  Item Category  \
# 0          840   48       1                     1              2
# 1         1718   29       1                     2              2
# 2          322   41       1                     3              3
# 3         3188   67       0                     4              2
# 4         2270   49       1                     5              2
# 5          367   64       1                     6              2
# 6         2645   25       1                     7              2
# 7         1750   43       1                     2              2
# 8         3606   68       0                     8              2
# 9         1097   57       1                     9              4
#
#    Purchase Amount (USD)  Location  Size  Color  Season  Review Rating  \
# 0                     31        13     3      1  Spring            2.6
# 1                     50        11     3      2  Summer            2.9
# 2                     36        45     3      2  Summer            4.7
# 3                     72        43     3      3  Winter            3.2
# 4                     38        17     2      4    Fall            4.4
# 5                     36        27     2      5  Spring            3.5
# 6                     83        31     2      5  Spring            3.3
# 7                     70        50     3      6    Fall            3.2
# 8                     41         1     2      7    Fall            4.3
# 9                     46        29     1      8    Fall            2.6
#
#   Subscription Status   Shipping Type Discount Applied Promo Code Used  \
# 0                 Yes   Free Shipping              Yes             Yes
# 1                  No         Express               No              No
# 2                 Yes   Free Shipping              Yes             Yes
# 3                  No   Free Shipping               No              No
# 4                  No    Store Pickup               No              No
# 5                 Yes    Store Pickup              Yes             Yes
# 6                  No        Standard               No              No
# 7                  No  2-Day Shipping               No              No
# 8                  No    Store Pickup               No              No
# 9                  No        Standard              Yes             Yes
#
#    Previous Purchases Payment Method Frequency of Purchases
# 0                  10     Debit Card         Every 3 Months
# 1                  16     Debit Card              Bi-Weekly
# 2                  48     Debit Card              Quarterly
# 3                  28     Debit Card                 Weekly
# 4                  27    Credit Card               Annually
# 5                  37          Venmo            Fortnightly
# 6                   4  Bank Transfer         Every 3 Months
# 7                  36     Debit Card         Every 3 Months
# 8                  36  Bank Transfer         Every 3 Months
# 9                  48    Credit Card               Annually

# %%
data['Season'].unique()
# Out:
# array(['Spring', 'Summer', 'Winter', 'Fall'], dtype=object)

# %%
data['Subscription Status'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
# Mapping for Season to numerical values
season_mapping = {
    'Spring': 1,
    'Summer': 2,
    'Fall': 3,
    'Winter': 4
}

# Map Season to numerical values
data['Season'] = data['Season'].map(season_mapping)

# %%
# Mapping for Subscription Status to numerical values
subscription_status_mapping = {
    'Yes': 1,
    'No': 0
}

# Map Subscription Status to numerical values
data['Subscription Status'] = data['Subscription Status'].map(subscription_status_mapping)
data.head(5)
# Out:
#    Customer ID  Age  Gender  Item(code) Purchased  Item Category  \
# 0          840   48       1                     1              2
# 1         1718   29       1                     2              2
# 2          322   41       1                     3              3
# 3         3188   67       0                     4              2
# 4         2270   49       1                     5              2
#
#    Purchase Amount (USD)  Location  Size  Color  Season  Review Rating  \
# 0                     31        13     3      1       1            2.6
# 1                     50        11     3      2       2            2.9
# 2                     36        45     3      2       2            4.7
# 3                     72        43     3      3       4            3.2
# 4                     38        17     2      4       3            4.4
#
#    Subscription Status  Shipping Type Discount Applied Promo Code Used  \
# 0                    1  Free Shipping              Yes             Yes
# 1                    0        Express               No              No
# 2                    1  Free Shipping              Yes             Yes
# 3                    0  Free Shipping               No              No
# 4                    0   Store Pickup               No              No
#
#    Previous Purchases Payment Method Frequency of Purchases
# 0                  10     Debit Card         Every 3 Months
# 1                  16     Debit Card              Bi-Weekly
# 2                  48     Debit Card              Quarterly
# 3                  28     Debit Card                 Weekly
# 4                  27    Credit Card               Annually

# %%
data['Shipping Type'].unique()
# Out:
# array(['Free Shipping', 'Express', 'Store Pickup', 'Standard',
#        '2-Day Shipping', 'Next Day Air'], dtype=object)

# %%
data['Discount Applied'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
data['Promo Code Used'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
# Mapping for Shipping Type to numerical values based on cost
shipping_type_mapping = {
    'Free Shipping': 0,
    'Standard': 1,
    '2-Day Shipping': 2,
    'Express': 3,
    'Next Day Air': 4,
    'Store Pickup': 5
}

# Map Shipping Type to numerical values
data['Shipping Type'] = data['Shipping Type'].map(shipping_type_mapping)

# %%
# Mapping for Discount Applied to numerical values
discount_mapping = {
    'Yes': 1,
    'No': 0
}

# Map Discount Applied to numerical values
data['Discount Applied'] = data['Discount Applied'].map(discount_mapping)

# %%
# Mapping for Promo Code Used to numerical values
promo_code_mapping = {
    'Yes': 1,
    'No': 0
}

# Map Promo Code Used to numerical values
data['Promo Code Used'] = data['Promo Code Used'].map(promo_code_mapping)
data.head(10)
# Out:
#    Customer ID  Age  Gender  Item(code) Purchased  Item Category  \
# 0          840   48       1                     1              2
# 1         1718   29       1                     2              2
# 2          322   41       1                     3              3
# 3         3188   67       0                     4              2
# 4         2270   49       1                     5              2
# 5          367   64       1                     6              2
# 6         2645   25       1                     7              2
# 7         1750   43       1                     2              2
# 8         3606   68       0                     8              2
# 9         1097   57       1                     9              4
#
#    Purchase Amount (USD)  Location  Size  Color  Season  Review Rating  \
# 0                     31        13     3      1       1            2.6
# 1                     50        11     3      2       2            2.9
# 2                     36        45     3      2       2            4.7
# 3                     72        43     3      3       4            3.2
# 4                     38        17     2      4       3            4.4
# 5                     36        27     2      5       1            3.5
# 6                     83        31     2      5       1            3.3
# 7                     70        50     3      6       3            3.2
# 8                     41         1     2      7       3            4.3
# 9                     46        29     1      8       3            2.6
#
#    Subscription Status  Shipping Type  Discount Applied  Promo Code Used  \
# 0                    1              0                 1                1
# 1                    0              3                 0                0
# 2                    1              0                 1                1
# 3                    0              0                 0                0
# 4                    0              5                 0                0
# 5                    1              5                 1                1
# 6                    0              1                 0                0
# 7                    0              2                 0                0
# 8                    0              5                 0                0
# 9                    0              1                 1                1
#
#    Previous Purchases Payment Method Frequency of Purchases
# 0                  10     Debit Card         Every 3 Months
# 1                  16     Debit Card              Bi-Weekly
# 2                  48     Debit Card              Quarterly
# 3                  28     Debit Card                 Weekly
# 4                  27    Credit Card               Annually
# 5                  37          Venmo            Fortnightly
# 6                   4  Bank Transfer         Every 3 Months
# 7                  36     Debit Card         Every 3 Months
# 8                  36  Bank Transfer         Every 3 Months
# 9                  48    Credit Card               Annually

# %%
data['Payment Method'].unique()
# Out:
# array(['Debit Card', 'Credit Card', 'Venmo', 'Bank Transfer', 'Cash',
#        'PayPal'], dtype=object)

# %%
data['Frequency of Purchases'].unique()
# Out:
# array(['Every 3 Months', 'Bi-Weekly', 'Quarterly', 'Weekly', 'Annually',
#        'Fortnightly', 'Monthly'], dtype=object)

# %%
# Mapping for Payment Method to numerical values based on benefits
payment_method_mapping = {
    'Credit Card': 5,      # High benefit (most common and reliable)
    'Debit Card': 4,       # Good benefit (also common)
    'PayPal': 3,           # Moderate benefit (popular for online transactions)
    'Venmo': 2,            # Less common, but gaining popularity
    'Bank Transfer': 1,    # Less convenient for quick purchases
    'Cash': 0              # Least beneficial for online business
}

# Map Payment Method to numerical values
data['Payment Method'] = data['Payment Method'].map(payment_method_mapping)

# %%
# Mapping for Frequency of Purchases to numerical values based on benefits
frequency_of_purchases_mapping = {
    'Weekly': 6,           # High benefit (most frequent)
    'Bi-Weekly': 5,        # High benefit (frequent, once every 2 weeks)
    'Fortnightly': 5,      # Same as Bi-Weekly
    'Monthly': 4,          # Good benefit
    'Every 3 Months': 3,   # Moderate benefit
    'Quarterly': 2,        # Less frequent
    'Annually': 1          # Least beneficial for revenue
}

# Map Frequency of Purchases to numerical values
data['Frequency of Purchases'] = data['Frequency of Purchases'].map(frequency_of_purchases_mapping)
data.head(10)
# Out:
#    Customer ID  Age  Gender  Item(code) Purchased  Item Category  \
# 0          840   48       1                     1              2
# 1         1718   29       1                     2              2
# 2          322   41       1                     3              3
# 3         3188   67       0                     4              2
# 4         2270   49       1                     5              2
# 5          367   64       1                     6              2
# 6         2645   25       1                     7              2
# 7         1750   43       1                     2              2
# 8         3606   68       0                     8              2
# 9         1097   57       1                     9              4
#
#    Purchase Amount (USD)  Location  Size  Color  Season  Review Rating  \
# 0                     31        13     3      1       1            2.6
# 1                     50        11     3      2       2            2.9
# 2                     36        45     3      2       2            4.7
# 3                     72        43     3      3       4            3.2
# 4                     38        17     2      4       3            4.4
# 5                     36        27     2      5       1            3.5
# 6                     83        31     2      5       1            3.3
# 7                     70        50     3      6       3            3.2
# 8                     41         1     2      7       3            4.3
# 9                     46        29     1      8       3            2.6
#
#    Subscription Status  Shipping Type  Discount Applied  Promo Code Used  \
# 0                    1              0                 1                1
# 1                    0              3                 0                0
# 2                    1              0                 1                1
# 3                    0              0                 0                0
# 4                    0              5                 0                0
# 5                    1              5                 1                1
# 6                    0              1                 0                0
# 7                    0              2                 0                0
# 8                    0              5                 0                0
# 9                    0              1                 1                1
#
#    Previous Purchases  Payment Method  Frequency of Purchases
# 0                  10               4                       3
# 1                  16               4                       5
# 2                  48               4                       2
# 3                  28               4                       6
# 4                  27               5                       1
# 5                  37               2                       5
# 6                   4               1                       3
# 7                  36               4                       3
# 8                  36               1                       3
# 9                  48               5                       1

# %%
import numpy as np

# Assuming Previous Purchases indicates the count of purchases before the current transaction.

# Feature: Total Spend (same as before, as it's the total of Purchase Amount)
data['Total Spend'] = data['Purchase Amount (USD)']  # Total spend is just the purchase amount for that transaction

# Feature: Average Spend (this would remain the same, but given the unique rows per customer, it's the same as total)
data['Average Spend'] = data['Total Spend']  # Since one row per customer, avg spend is the same as total

# Feature: Purchase Frequency (number of previous purchases + current one)
data['Purchase Frequency'] = data['Previous Purchases'] + 1  # Add 1 for the current purchase

# Feature: Customer Lifetime Value (CLV) - based only on the current purchase
data['Customer Lifetime Value'] = data['Average Spend'] * data['Purchase Frequency']

# Feature: Loyalty Score (based on frequency of purchases and subscription status)
data['Loyalty Score'] = np.where(data['Subscription Status'] == 1, data['Purchase Frequency'] * 2, data['Purchase Frequency'])
data.head(10)
# Out:
#    Customer ID  Age  Gender  Item(code) Purchased  Item Category  \
# 0          840   48       1                     1              2
# 1         1718   29       1                     2              2
# 2          322   41       1                     3              3
# 3         3188   67       0                     4              2
# 4         2270   49       1                     5              2
# 5          367   64       1                     6              2
# 6         2645   25       1                     7              2
# 7         1750   43       1                     2              2
# 8         3606   68       0                     8              2
# 9         1097   57       1                     9              4
#
#    Purchase Amount (USD)  Location  Size  Color  Season  Review Rating  \
# 0                     31        13     3      1       1            2.6
# 1                     50        11     3      2       2            2.9
# 2                     36        45     3      2       2            4.7
# 3                     72        43     3      3       4            3.2
# 4                     38        17     2      4       3            4.4
# 5                     36        27     2      5       1            3.5
# 6                     83        31     2      5       1            3.3
# 7                     70        50     3      6       3            3.2
# 8                     41         1     2      7       3            4.3
# 9                     46        29     1      8       3            2.6
#
#    Subscription Status  Shipping Type  Discount Applied  Promo Code Used  \
# 0                    1              0                 1                1
# 1                    0              3                 0                0
# 2                    1              0                 1                1
# 3                    0              0                 0                0
# 4                    0              5                 0                0
# 5                    1              5                 1                1
# 6                    0              1                 0                0
# 7                    0              2                 0                0
# 8                    0              5                 0                0
# 9                    0              1                 1                1
#
#    Previous Purchases  Payment Method  Frequency of Purchases  Total Spend  \
# 0                  10               4                       3           31
# 1                  16               4                       5           50
# 2                  48               4                       2           36
# 3                  28               4                       6           72
# 4                  27               5                       1           38
# 5                  37               2                       5           36
# 6                   4               1                       3           83
# 7                  36               4                       3           70
# 8                  36               1                       3           41
# 9                  48               5                       1           46
#
#    Average Spend  Purchase Frequency  Customer Lifetime Value  Loyalty Score
# 0             31                  11                      341             22
# 1             50                  17                      850             17
# 2             36                  49                     1764             98
# 3             72                  29                     2088             29
# 4             38                  28                     1064             28
# 5             36                  38                     1368             76
# 6             83                   5                      415              5
# 7             70                  37                     2590             37
# 8             41                  37                     1517             37
# 9             46                  49                     2254             49

# %%
data[data.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Customer ID, Age, Gender, Item(code) Purchased, Item Category, Purchase Amount (USD), Location, Size, Color, Season, Review Rating, Subscription Status, Shipping Type, Discount Applied, Promo Code Used, Previous Purchases, Payment Method, Frequency of Purchases, Total Spend, Average Spend, Purchase Frequency, Customer Lifetime Value, Loyalty Score]
# Index: []

# %%
data.to_csv('step_1_Preprocessing.csv', index=False)
